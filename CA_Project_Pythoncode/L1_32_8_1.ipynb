# %%
# L1 parameters:number of set:32  block size:8  set associativity:1

import numpy as np
import matplotlib.pyplot as plt

# %%
# Fixed L2 set associativity:1-way

x1=[32,64,128,256,512]
y1=[0.2711,0.2168,0.1791,0.1337,0.0876]
x2=[32,64,128,256,512]
y2=[0.1374,0.1153,0.0869,0.0593,0.0249]
x3=[32,64,128,256,512]
y3=[0.0805,0.0602,0.0434,0.0168,0.0052]
x4=[32,64,128,256,512]
y4=[0.0392,0.0286,0.014,0.003,0.0015]
x5=[32,64,128,256,512]
y5=[0.0187,0.0093,0.002,0.0009,0.0009]
x6=[32,64,128,256,512]
y6=[0.0081,0.0016,0.0005,0.0005,0.0005]

l1=plt.plot(x1,y1,'r--',label='L2 block size:32')
l2=plt.plot(x2,y2,'g--',label='L2 block size:64')
l3=plt.plot(x3,y3,'b--',label='L2 block size:128')
l4=plt.plot(x4,y4,'k--',label='L2 block size:256')
l5=plt.plot(x5,y5,'c--',label='L2 block size:512')
l6=plt.plot(x6,y6,'m--',label='L2 block size:1024')

plt.plot(x1,y1,'ro-',x2,y2,'go-',x3,y3,'bo-',x4,y4,'ko-',x5,y5,'co-',x6,y6,'mo-')

plt.xlabel('The number of sets in L2')
plt.ylabel('Miss rate')

plt.title('L1 block size:8 bytes and Fixed L2 set associativity:1-way')
plt.legend()
plt.savefig('E:\\CA_plot\\fig_1.png')
plt.show()

# %%
# Fixed L2 set associativity:2-way

x1=[32,64,128,256,512]
y1=[0.2073,0.1638,0.1241,0.0759,0.0305]
x2=[32,64,128,256,512]
y2=[0.1032,0.0779,0.05,0.0219,0.006]
x3=[32,64,128,256,512]
y3=[0.0506,0.0347,0.0155,0.0036,0.0029]
x4=[32,64,128,256,512]
y4=[0.0215,0.0114,0.0021,0.0015,0.0015]
x5=[32,64,128,256,512]
y5=[0.0088,0.0013,0.0009,0.0009,0.0009]
x6=[32,64,128,256,512]
y6=[0.0012,0.0005,0.0005,0.0005,0.0005]

l1=plt.plot(x1,y1,'r--',label='L2 block size:32')
l2=plt.plot(x2,y2,'g--',label='L2 block size:64')
l3=plt.plot(x3,y3,'b--',label='L2 block size:128')
l4=plt.plot(x4,y4,'k--',label='L2 block size:256')
l5=plt.plot(x5,y5,'c--',label='L2 block size:512')
l6=plt.plot(x6,y6,'m--',label='L2 block size:1024')

plt.plot(x1,y1,'ro-',x2,y2,'go-',x3,y3,'bo-',x4,y4,'ko-',x5,y5,'co-',x6,y6,'mo-')

plt.xlabel('The number of sets in L2')
plt.ylabel('Miss rate')

plt.title('L1 block size:8 bytes and Fixed L2 set associativity:2-way')
plt.legend()
plt.savefig('E:\\CA_plot\\fig_2.png')
plt.show()

# %%
# Fixed L2 set size: 32

x1=[32,64,128,256,512,1024]
y1=[0.2711,0.1374,0.0805,0.0392,0.0224,0.0081]
x2=[32,64,128,256,512,1024]
y2=[0.2073,0.1032,0.0506,0.0215,0.0088,0.0012]
x3=[32,64,128,256,512,1024]
y3=[0.1655,0.0706,0.0359,0.012,0.001,0.0005]
x4=[32,64,128,256,512,1024]
y4=[0.1155,0.0569,0.0129,0.0016,0.0009,0.0005]
x5=[32,64,128,256,512,1024]
y5=[0.0867,0.0091,0.0029,0.0016,0.0009,0.0005]

l1=plt.plot(x1,y1,'r--',label='Set associativity:1-way')
l2=plt.plot(x2,y2,'g--',label='Set associativity:2-way')
l3=plt.plot(x3,y3,'b--',label='Set associativity:4-way')
l4=plt.plot(x4,y4,'k--',label='Set associativity:8-way')
l5=plt.plot(x5,y5,'c--',label='Set associativity:16-way')

plt.plot(x1,y1,'ro-',x2,y2,'go-',x3,y3,'bo-',x4,y4,'ko-',x5,y5,'co-')

plt.xlabel('L2 block size')
plt.ylabel('Miss rate')

plt.title('L1 block size:8 bytes and Fixed L2 set size:32')
plt.legend()
plt.savefig('E:\\CA_plot\\fig_3.png')
plt.show()

# %%
# Fixed set size: 64

x1=[32,64,128,256,512,1024]
y1=[0.2168,0.1153,0.0602,0.0286,0.0093,0.0016]
x2=[32,64,128,256,512,1024]
y2=[0.1638,0.0779,0.0347,0.0114,0.0013,0.0005]
x3=[32,64,128,256,512,1024]
y3=[0.1146,0.0534,0.0159,0.0016,0.0009,0.0005]
x4=[32,64,128,256,512,1024]
y4=[0.0854,0.0109,0.0029,0.0015,0.0009,0.0005]
x5=[32,64,128,256,512,1024]
y5=[0.0119,0.0051,0.0029,0.0015,0.0009,0.0005]

l1=plt.plot(x1,y1,'r--',label='Set associativity:1-way')
l2=plt.plot(x2,y2,'g--',label='Set associativity:2-way')
l3=plt.plot(x3,y3,'b--',label='Set associativity:4-way')
l4=plt.plot(x4,y4,'k--',label='Set associativity:8-way')
l5=plt.plot(x5,y5,'c--',label='Set associativity:16-way')

plt.plot(x1,y1,'ro-',x2,y2,'go-',x3,y3,'bo-',x4,y4,'ko-',x5,y5,'co-')

plt.xlabel('L2 block size')
plt.ylabel('Miss rate')

plt.title('L1 block size:8 bytes and Fixed L2 set size:64')
plt.legend()
plt.savefig('E:\\CA_plot\\fig_4.png')
plt.show()
