# %%
# L1 parameters:number of set:32  block size:16  set associativity:1

import numpy as np
import matplotlib.pyplot as plt

# %%
# Fixed L2 set associativity:1-way

x1=[32,64,128,256,512]
y1=[0.5246,0.4209,0.3489,0.2604,0.1706]
x2=[32,64,128,256,512]
y2=[0.2665,0.2243,0.1692,0.1154,0.0481]
x3=[32,64,128,256,512]
y3=[0.1563,0.1171,0.0845,0.0327,0.0101]
x4=[32,64,128,256,512]
y4=[0.0761,0.0556,0.023,0.0059,0.003]
x5=[32,64,128,256,512]
y5=[0.0431,0.0179,0.0039,0.0017,0.0017]
x6=[32,64,128,256,512]
y6=[0.0157,0.0031,0.0009,0.0009,0.0009]

l1=plt.plot(x1,y1,'r--',label='L2 block size:32')
l2=plt.plot(x2,y2,'g--',label='L2 block size:64')
l3=plt.plot(x3,y3,'b--',label='L2 block size:128')
l4=plt.plot(x4,y4,'k--',label='L2 block size:256')
l5=plt.plot(x5,y5,'c--',label='L2 block size:512')
l6=plt.plot(x6,y6,'m--',label='L2 block size:1024')

plt.plot(x1,y1,'ro-',x2,y2,'go-',x3,y3,'bo-',x4,y4,'ko-',x5,y5,'co-',x6,y6,'mo-')

plt.xlabel('The number os sets in L2')
plt.ylabel('Miss rate')

plt.title('L1 block size:16 bytes and Fixed L2 set associativity:1-way')
plt.legend()
plt.savefig('E:\\CA_plot\\fig_5.png')
plt.show()

# %%
# Fixed L2 set associativity:2-way

x1=[32,64,128,256,512]
y1=[0.4039,0.3199,0.2417,0.1477,0.0595]
x2=[32,64,128,256,512]
y2=[0.2017,0.1516,0.0974,0.0427,0.0118]
x3=[32,64,128,256,512]
y3=[0.0983,0.0076,0.0303,0.0069,0.0056]
x4=[32,64,128,256,512]
y4=[0.0419,0.0222,0.0041,0.003,0.003]
x5=[32,64,128,256,512]
y5=[0.0172,0.0025,0.0017,0.0017,0.0017]
x6=[32,64,128,256,512]
y6=[0.0024,0.0009,0.0009,0.0009,0.0009]

l1=plt.plot(x1,y1,'r--',label='L2 block size:32')
l2=plt.plot(x2,y2,'g--',label='L2 block size:64')
l3=plt.plot(x3,y3,'b--',label='L2 block size:128')
l4=plt.plot(x4,y4,'k--',label='L2 block size:256')
l5=plt.plot(x5,y5,'c--',label='L2 block size:512')
l6=plt.plot(x6,y6,'m--',label='L2 block size:1024')

plt.plot(x1,y1,'ro-',x2,y2,'go-',x3,y3,'bo-',x4,y4,'ko-',x5,y5,'co-',x6,y6,'mo-')

plt.xlabel('The number os sets in L2')
plt.ylabel('Miss rate')

plt.title('L1 block size:16 bytes and Fixed L2 set associativity:2-way')
plt.legend()
plt.savefig('E:\\CA_plot\\fig_6.png')
plt.show()

# %%
# Fixed L2 set size: 32

x1=[32,64,128,256,512,1024]
y1=[0.5246,0.2665,0.1563,0.0761,0.0433,0.0157]
x2=[32,64,128,256,512,1024]
y2=[0.4039,0.2017,0.0983,0.0419,0.0172,0.0024]
x3=[32,64,128,256,512,1024]
y3=[0.3223,0.1377,0.0699,0.0233,0.0019,0.0009]
x4=[32,64,128,256,512,1024]
y4=[0.2712,0.1109,0.0212,0.0031,0.0017,0.0009]
x5=[32,64,128,256,512,1024]
y5=[0.1689,0.0177,0.0056,0.003,0.0017,0.0009]

l1=plt.plot(x1,y1,'r--',label='Set associativity:1-way')
l2=plt.plot(x2,y2,'g--',label='Set associativity:2-way')
l3=plt.plot(x3,y3,'b--',label='Set associativity:4-way')
l4=plt.plot(x4,y4,'k--',label='Set associativity:8-way')
l5=plt.plot(x5,y5,'c--',label='Set associativity:16-way')

plt.plot(x1,y1,'ro-',x2,y2,'go-',x3,y3,'bo-',x4,y4,'ko-',x5,y5,'co-')

plt.xlabel('L2 block size')
plt.ylabel('Miss rate')

plt.title('L1 block size:16 bytes and Fixed L2 set size:32')
plt.legend()
plt.savefig('E:\\CA_plot\\fig_7.png')
plt.show()

# %%
# Fixed set size: 64

x1=[32,64,128,256,512,1024]
y1=[0.4209,0.2243,0.1171,0.0556,0.0179,0.0031]
x2=[32,64,128,256,512,1024]
y2=[0.2424,0.1516,0.0676,0.0222,0.0025,0.0009]
x3=[32,64,128,256,512,1024]
y3=[0.2232,0.1041,0.0309,0.0031,0.0017,0.0009]
x4=[32,64,128,256,512,1024]
y4=[0.1664,0.0212,0.0056,0.003,0.0017,0.0009]
x5=[32,64,128,256,512,1024]
y5=[0.0233,0.01,0.0056,0.003,0.0017,0.0009]

l1=plt.plot(x1,y1,'r--',label='Set associativity:1-way')
l2=plt.plot(x2,y2,'g--',label='Set associativity:2-way')
l3=plt.plot(x3,y3,'b--',label='Set associativity:4-way')
l4=plt.plot(x4,y4,'k--',label='Set associativity:8-way')
l5=plt.plot(x5,y5,'c--',label='Set associativity:16-way')

plt.plot(x1,y1,'ro-',x2,y2,'go-',x3,y3,'bo-',x4,y4,'ko-',x5,y5,'co-')

plt.xlabel('L2 block size')
plt.ylabel('Miss rate')

plt.title('L1 block size:16 bytes and Fixed L2 set size:64')
plt.legend()
plt.savefig('E:\\CA_plot\\fig_8.png')
plt.show()

# %%
# Fixed block size: 16 bytes

x1=[1,2,4,8,16]
y1=[0.435206,0.350867,0.263653,0.191522,0.140893]
x2=[1,2,4,8,16]
y2=[0.367983,0.268582,0.206066,0.142699,0.10031]
x3=[1,2,4,8,16]
y3=[0.297001,0.205985,0.14382,0.098659,0.018376]
x4=[1,2,4,8,16]
y4=[0.249322,0.158066,0.094212,0.021602,0.014973]
x5=[1,2,4,8,16]
y5=[0.190061,0.098087,0.037574,0.015113,0.014884]

l1=plt.plot(x1,y1,'r--',label='Set size:32')
l2=plt.plot(x2,y2,'g--',label='Set size:64')
l3=plt.plot(x3,y3,'b--',label='Set size:128')
l4=plt.plot(x4,y4,'k--',label='Set size:256')
l5=plt.plot(x5,y5,'c--',label='Set size:512')

plt.plot(x1,y1,'ro-',x2,y2,'go-',x3,y3,'bo-',x4,y4,'ko-',x5,y5,'co-')

plt.xlabel('n-way associativity')
plt.ylabel('Miss rate')

plt.title('L1 block size:16 bytes and Fixed block size:16 bytes')
plt.legend()
plt.savefig('E:\\CA_plot\\fig_9.png')
plt.show()

# %%
# Fixed block size: 32 bytes

x1=[1,2,4,8,16]
y1=[0.249344,0.172416,0.13155,0.084637,0.069436]
x2=[1,2,4,8,16]
y2=[0.195577,0.129577,0.087897,0.067751,0.01203]
x3=[1,2,4,8,16]
y3=[0.161893,0.098286,0.062442,0.015861,0.008104]
x4=[1,2,4,8,16]
y4=[0.124976,0.06406,0.026269,0.008248,0.00803]
x5=[1,2,4,8,16]
y5=[0.078495,0.028253,0.008307,0.00803,0.00803]

l1=plt.plot(x1,y1,'r--',label='Set size:32')
l2=plt.plot(x2,y2,'g--',label='Set size:64')
l3=plt.plot(x3,y3,'b--',label='Set size:128')
l4=plt.plot(x4,y4,'k--',label='Set size:256')
l5=plt.plot(x5,y5,'c--',label='Set size:512')

plt.plot(x1,y1,'ro-',x2,y2,'go-',x3,y3,'bo-',x4,y4,'ko-',x5,y5,'co-')

plt.xlabel('n-way associativity')
plt.ylabel('Miss rate')

plt.title('L1 block size:16 bytes and Fixed block size:32 bytes')
plt.legend()
plt.savefig('E:\\CA_plot\\fig_10.png')
plt.show()
